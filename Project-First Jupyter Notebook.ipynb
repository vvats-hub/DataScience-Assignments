# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Vandita Vats**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because it is one of the most exciting career opportunity in current time. It gives you opportunity to explore data and understand it by drawing patterns. It involes AI and machine learning which have always been my favorite subjects to study and to take forward as a career.*

# %% [markdown]
# ### The following code is used to swap two numbers :

# %%
x = 10
y = 20
x = x+y
y = x-y
x = x-y
x , y
# Out:
# (20, 10)

# %% [markdown]
# > Below is an employee record
#
# EMP|NAME|DEPARTMENT
# ---|---|---
# 124|Jack Willson|Engineering
# 345|Tom Steven|Human Resource
# 656|Kevin Bernett|Engineering
#
# * There are two employees in Engineering department
# * One employee is from HR department
#
# > Below is the latest news for Employees :
#
# 1. Farewell of Mr Thomson is not being held anymore as he is not leaving the firm.
# 2. New bonuses will be anounces next week.
# 3. There will be a free [lunch](www.google.com) in cafeteria on wednesday.
